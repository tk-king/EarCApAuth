# %%
import pandas as pd

# %%
data = pd.read_csv('s1-filt')

# %%
data.head()
# Out:
#     s1     s2     s3     s4     s5     s6     s7     s8     s9    s10    s11
# 0  320  290.0  290.0  285.0  286.0  263.0  263.0  252.0  264.0  264.0  268.0  \
# 1  320  290.0  290.0  285.0  286.0  263.0  263.0  252.0  264.0  264.0  268.0
# 2  320  291.0  290.0  285.0  286.0  263.0  263.0  252.0  264.0  264.0  268.0
# 3  320  291.0  290.0  285.0  286.0  264.0  264.0  252.0  264.0  264.0  268.0
# 4  320  290.0  290.0  285.0  286.0  264.0  263.0  252.0  264.0  264.0  268.0
#
#      s12    s13    s14    s15    s16    s17    s18    s19    s20
# 0  250.0  274.0  253.0  238.0  247.0  236.0  231.0  241.0  248.0
# 1  250.0  274.0  253.0  238.0  247.0  236.0  231.0  241.0  247.0
# 2  250.0  274.0  253.0  238.0  247.0  236.0  231.0  241.0  248.0
# 3  250.0  274.0  253.0  238.0  247.0  236.0  231.0  241.0  248.0
# 4  250.0  274.0  253.0  238.0  247.0  236.0  231.0  241.0  248.0

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('s1-3fl')

# %%
data
# Out:
#      s1   s2
# 0    83  320
# 1    89  290
# 2   265  290
# 3   254  285
# 4   260  286
# 5    82  263
# 6   239  263
# 7   248  252
# 8   261  264
# 9   161  264
# 10  266  268
# 11  250  250
# 12  264  274
# 13  249  253
# 14  236  238
# 15  241  247
# 16  233  236
# 17  131  231
# 18  195  241
# 19  197  248

# %%
plt.plot(data.s1)
plt.plot(data.s2)

# %%
d1 = pd.read_csv('m2-flt')

# %%
d3 = pd.read_csv('mall')

# %%
d1 = pd.read_csv('m1-flt')
d2 = pd.read_csv('m2-flt')
d3 = pd.read_csv('m3-flt')
d4 = pd.read_csv('m4-flt')
d5 = pd.read_csv('m5-flt')
d6 = pd.read_csv('m6-flt')
dm = pd.read_csv('mall2')

# %%
fehl = pd.read_csv('fehl')

# %%
plt.plot(fehl.s1)

# %%
plt.plot(d2.s1)
plt.plot(d2.s2)
plt.plot(d2.s3)
plt.plot(d2.s4)
plt.plot(d2.s5)
plt.plot(d2.s6)
plt.plot(d2.s7)
plt.plot(d2.s8)
plt.plot(d2.s9)
plt.plot(d2.s10)

# %%
plt.plot(d3.s1)
plt.plot(d3.s2)
plt.plot(d3.s3)
plt.plot(d3.s4)
plt.plot(d3.s5)
plt.plot(d3.s6)
plt.plot(d3.s7)
plt.plot(d3.s8)
plt.plot(d3.s9)
plt.plot(d3.s10)
plt.plot(d3.s11)
plt.plot(d3.s12)
plt.plot(d3.s13)
plt.plot(d3.s14)
plt.plot(d3.s15)
plt.plot(d3.s16)
plt.plot(d3.s17)
plt.plot(d3.s18)
plt.plot(d3.s19)
plt.plot(d3.s20)

# %% [markdown]
# ## import numpy as np
# def sq_err(array, array2):
#     err = 0
#     if len(array) != len(array2):
#         raise Exception("same length required")
#     for i in range(len(array)):
#         err2 = array[i] - array2[i]
#         err = err + (err2 * err2)
#     return err
# datrr = []
# for i in range(20):
#     datrr.append([])
# for i in d3.values:
#     for j in range(20):
#         if not pd.isnull(i[j]) and i[j] != '--':
#             datrr[j].append(i[j])
# print(d1.values[0])
# err_arr = []
# for i in d3.values:
#     err_arr.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],d1.values[11].tolist())) # Methode der kleinsten Fehlerquadrate    print(err_arr)
#
#
# print(err_arr)
# plt.plot(err_arr)
# err_arr2 = []
# for i in d1.values:
#     err_arr2.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],d1.values[11].tolist()))
# print(err_arr2)
# plt.plot(err_arr2)

# %%
import numpy as np


def sq_err(array, array2):
    err = 0
    if len(array) != len(array2):
        raise Exception("same length required")
    for i in range(len(array)):
        err2 = array[i] - array2[i]
        err = err + (err2 * err2)
    return err



datrr = []
for i in range(20):
    datrr.append([])
for i in d3.values:
    for j in range(20):
        if not pd.isnull(i[j]) and i[j] != '--':
            datrr[j].append(i[j])
print(d1.values[0])
def cp_av(data):
    r1 = 0
    ret = []
    for i in range(20):
        r1 = 0
        for j in range(20):
            r1 = r1 + data.values[i].tolist()[i]
        ret.append(r1 / 20)
    return ret

err_arr = []
err_arr1 = [] # error mit 1 als referenz
err_arr2 = [] # error mit 2 als referenz
err_arr3 = [] # error mit 3 als referenz
err_arr4 = [] # error mit 4 als referenz
err_arr5 = [] # error mit 1 als referenz
err_arr6 = [] # error mit 1 als referenz

good_arr1 = [] # selbsttest von 1 als referenz
good_arr2 = [] # error mit 2 als referenz
good_arr3 = [] # error mit 3 als referenz
good_arr4 = [] # error mit 4 als referenz
good_arr5 = [] # error mit 1 als referenz
good_arr6 = [] # error mit 1 als referenz

ref1 = d1.values[11].tolist()
ref2 = d2.values[11].tolist()
ref3 = d3.values[11].tolist()
ref4 = d4.values[11].tolist()
ref5 = d5.values[11].tolist()
ref6 = d6.values[11].tolist()


ref1 = []
ref2 = []
ref3 = []
ref4 = []
ref5 = []
ref6 = []

ref1 = cp_av(d1)
ref2 = cp_av(d2)
ref3 = cp_av(d3)
ref4 = cp_av(d4)
ref5 = cp_av(d5)
ref6 = cp_av(d6)

print(ref1)


for i in d1.values: 
    err_arr2.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref2)) 
    # Methode der kleinsten Fehlerquadrate    print(err_arr)
    err_arr3.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref3))
    err_arr4.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref4))
    err_arr5.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref5))
    err_arr6.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref6))
    good_arr1.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref1))

for i in d2.values:
    err_arr1.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref1)) 
    # Methode der kleinsten Fehlerquadrate    print(err_arr)
    err_arr3.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref3))
    err_arr4.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref4))
    err_arr5.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref5))
    err_arr6.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref6))
    good_arr2.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref2))

for i in d3.values:
    err_arr2.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref2)) 
    # Methode der kleinsten Fehlerquadrate    print(err_arr)
    err_arr1.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref1))
    err_arr4.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref4))
    err_arr5.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref5))
    err_arr6.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref6))
    good_arr3.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref3))
    
for i in d4.values:
    err_arr2.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref2)) 
    # Methode der kleinsten Fehlerquadrate    print(err_arr)
    err_arr3.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref3))
    err_arr1.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref1))
    err_arr5.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref5))
    err_arr6.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref6))
    good_arr4.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref4))
    
for i in d5.values:
    err_arr2.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref2)) 
    # Methode der kleinsten Fehlerquadrate    print(err_arr)
    err_arr3.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref3))
    err_arr4.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref4))
    err_arr1.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref1))
    err_arr6.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref6))
    good_arr5.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref5))
    
for i in d6.values:
    err_arr2.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref2)) 
    # Methode der kleinsten Fehlerquadrate    print(err_arr)
    err_arr3.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref3))
    err_arr4.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref4))
    err_arr5.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref5))
    err_arr1.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref1))
    good_arr6.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],ref6))

print(err_arr)
plt.plot(err_arr1)
plt.plot(err_arr2)
plt.plot(err_arr3)
plt.plot(err_arr4)
plt.plot(err_arr5)
plt.plot(err_arr6)
plt.show()
plt.plot(good_arr1)
plt.plot(good_arr2)
plt.plot(good_arr3)
plt.plot(good_arr4)
plt.plot(good_arr5)
plt.plot(good_arr6)
plt.show()
good1 = 0
bad1 = 0
thresh = 70000
errs = [err_arr1, err_arr2, err_arr3, err_arr4, err_arr5, err_arr6]
goods = [good_arr1, good_arr2, good_arr3, good_arr4, good_arr5, good_arr6]
for j in errs:
    for i in j:
        if i > thresh:
            good1 = good1 + 1
        else:
            bad1 = bad1 + 1
print(good1)
print(bad1)

good2 = 0
bad2 = 0
for j in goods:
    for i in j:
        if i <= thresh:
            good2 = good2 + 1
        else:
            bad2 = bad2 + 1
print(good2)
print(bad2)

    
err_arr2 = []
#for i in d1.values:
#    err_arr2.append(sq_err([int(numeric_string) for numeric_string in i.tolist()],d1.values[11].tolist()))
#print(err_arr2)
#plt.plot(err_arr2)
# Out:
# [ 88  88 283 191 271 259  55  27 238 210 267 249 268 251 232 133  27 191
#  229 228]
# [88.0, 89.0, 283.0, 191.0, 271.0, 259.0, 55.0, 26.0, 238.0, 210.0, 267.0, 249.0, 268.0, 251.0, 232.0, 187.0, 31.0, 175.0, 230.0, 227.0]
# []
# 1451
# 349
# 310
# 50

# %%
plt.plot(d1.s1)
plt.plot(d1.s2)
plt.plot(d1.s3)
plt.plot(d1.s4)
plt.plot(d1.s5)
plt.plot(d1.s6)
plt.plot(d1.s7)
plt.plot(d1.s8)
plt.plot(d1.s9)
plt.plot(d1.s10)
